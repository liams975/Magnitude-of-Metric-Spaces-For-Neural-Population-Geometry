# %% [markdown]
# # Setup
#
# One-time environment + data setup for week 1. The actual analysis pipeline (session loading, the frozen Wiener filter, per-session R^2, the degradation figure) is **not** implemented in notebooks -- see `src/` and run `make figure1`. This notebook is just what downloads the raw data, matching `CONTEXT.md` / `notes/redirect-memo.md`.

# %%
# %pip install -q falcon-challenge dandi

# %%
# M1, monkey reach-grasp; M2, monkey finger. -o already-populated dirs are skipped by dandi.
# !mkdir -p data/000941 data/000953
# !dandi download -o data/000941 https://dandiarchive.org/dandiset/000941/draft
# !dandi download -o data/000953 https://dandiarchive.org/dandiset/000953/draft

# %% [markdown]
# Both are downloaded as of 9 Sept 2026: M1 (`000941`, 311.8 MB, 11 sessions) and M2 (`000953`, 15.9 GB, 20 sessions). See `results/sessions_manifest.csv` for the per-session index and `figures/fig1_degradation_m1.png` for the week-1 deliverable, both produced by `make figure1`.
